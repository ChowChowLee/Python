# %%
import pandas as pd
import numpy as np
from scipy.stats import gmean
pd.options.display.max_columns = None

# %%
output_file_path = "C:\\Users\\Lee\\PycharmProjects\\pythonProjectAlpacaBaby\\Python\\ML_Thesis\\output_data\\"
input_file_path = "C:\\Users\\Lee\\PycharmProjects\\pythonProjectAlpacaBaby\\Python\\ML_Thesis\\input_data\\"
df_raw = pd.read_csv(input_file_path + "sludgeDatasetMerge.tsv", sep='\t')

# %%
df_raw.head()
# Out:
#   index                                        scenario_id  \
# 0     1  https://envipath.org/package/4a3cd0f4-4d2b-4f0...
# 1     2  https://envipath.org/package/4a3cd0f4-4d2b-4f0...
# 2     3  https://envipath.org/package/4a3cd0f4-4d2b-4f0...
# 3     4  https://envipath.org/package/4a3cd0f4-4d2b-4f0...
# 4     5  https://envipath.org/package/4a3cd0f4-4d2b-4f0...
#
#                                          compound_id  \
# 0  https://envipath.org/package/4a3cd0f4-4d2b-4f0...
# 1  https://envipath.org/package/4a3cd0f4-4d2b-4f0...
# 2  https://envipath.org/package/4a3cd0f4-4d2b-4f0...
# 3  https://envipath.org/package/4a3cd0f4-4d2b-4f0...
# 4  https://envipath.org/package/4a3cd0f4-4d2b-4f0...
#
#                    compound_name                             smiles  \
# 0  1-(3-chlorophenyl) piperazine          C1=CC(=C(C=C1)N2CCNCC2)Cl
# 1  1-(3-chlorophenyl) piperazine          C1=CC(=C(C=C1)N2CCNCC2)Cl
# 2  1-(3-chlorophenyl) piperazine          C1=CC(=C(C=C1)N2CCNCC2)Cl
# 3         17-beta-estradiol (E2)  CC12CCC3C4=CC=C(C=C4CCC3C2CCC1O)O
# 4         17-beta-estradiol (E2)  CC12CCC3C4=CC=C(C=C4CCC3C2CCC1O)O
#
#               canonicalize_smiles halflife halflife_unit halflife_model  \
# 0              Clc1ccccc1N1CCNCC1      NaN           NaN            NaN
# 1              Clc1ccccc1N1CCNCC1      NaN           NaN            NaN
# 2              Clc1ccccc1N1CCNCC1      NaN           NaN            NaN
# 3  CC12CCC3c4ccc(O)cc4CCC3C1CCC2O      NaN           NaN            NaN
# 4  CC12CCC3c4ccc(O)cc4CCC3C1CCC2O      NaN           NaN            NaN
#
#   halflife_comment rateconstant  rateconstant_unit  \
# 0              NaN         0.33  L / (g TSS * day)
# 1              NaN          1.3  L / (g TSS * day)
# 2              NaN        0.056  L / (g TSS * day)
# 3              NaN         14.4            1 / day
# 4              NaN         7.68            1 / day
#
#                      rateconstant_comment      reaction_order acidity  \
# 0    90% credibility interval: 0.26, 0.46  Pseudo first order     7.1
# 1      90% credibility interval: 1.0, 1.6  Pseudo first order     8.1
# 2  90% credibility interval: 0.037, 0.076  Pseudo first order     6.3
# 3                              no comment         First order     7.8
# 4                              no comment         First order     7.8
#
#   acidity_unit temperature temperature_unit original_sludge_amount  \
# 0           pH        23.0                ℃                   50.0
# 1           pH        21.0                ℃                   50.0
# 2           pH        21.0                ℃                   50.0
# 3           pH        30.0                ℃                  100.0
# 4           pH        30.0                ℃                  100.0
#
#   original_sludge_amount_unit sludge_retention_time  \
# 0                          mL                  25.0
# 1                          mL                  25.0
# 2                          mL                  25.0
# 3                          mL                   NaN
# 4                          mL                   NaN
#
#   sludge_retention_time_unit sludge_retention_time_type  \
# 0                          d                 sludge age
# 1                          d                 sludge age
# 2                          d                 sludge age
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#   total_suspended_solids_concentration_start  \
# 0                                        1.9
# 1                                        2.3
# 2                                        2.0
# 3                                        2.7
# 4                                        0.7
#
#   total_suspended_solids_concentration_end  \
# 0                                      2.5
# 1                                      2.3
# 2                                      2.1
# 3                                      2.7
# 4                                      0.7
#
#   total_suspended_solids_concentration_unit  \
# 0                                       g/L
# 1                                       g/L
# 2                                       g/L
# 3                                       g/L
# 4                                       g/L
#
#                              addition_of_nutrients  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4  Allylthiourea as inhibitor of ammonia oxidation
#
#                      biological_treatment_technology      bioreactor_type  \
# 0  nitrification & denitrification & biological p...  amber Schott bottle
# 1  nitrification & denitrification & biological p...  amber Schott bottle
# 2  nitrification & denitrification & biological p...  amber Schott bottle
# 3                                      nitrification     Erlemeyer flasks
# 4                                      nitrification     Erlemeyer flasks
#
#   bioreactor_value bioreactor_value_unit nitrogen_content_type  \
# 0            100.0                    mL                   NaN
# 1            100.0                    mL                   NaN
# 2            100.0                    mL                   NaN
# 3            200.0                    mL                   NaN
# 4            200.0                    mL                   NaN
#
#   nitrogen_content_influent oxygen_demand_type oxygen_demand_value  \
# 0                       NaN                NaN                 NaN
# 1                       NaN                NaN                 NaN
# 2                       NaN                NaN                 NaN
# 3                       NaN                NaN                 NaN
# 4                       NaN                NaN                 NaN
#
#   oxygen_uptake_rate oxygen_uptake_rate_unit phosphorus_content  redox  \
# 0                NaN              mg/(L * h)                NaN  aerob
# 1                NaN              mg/(L * h)                NaN  aerob
# 2                NaN              mg/(L * h)                NaN  aerob
# 3                NaN                     NaN                NaN  aerob
# 4                NaN                     NaN                NaN  aerob
#
#                              source_of_liquid_matrix    type_of_addition  \
# 0                                          tap water  spiking in solvent
# 1                                          tap water  spiking in solvent
# 2                                          tap water  spiking in solvent
# 3  mineral salt medium [(NH4)2SO4, 6.6 g/L; KH2PO...  spiking in solvent
# 4  mineral salt medium [(NH4)2SO4, 6.6 g/L; KH2PO...  spiking in solvent
#
#             type_of_aeration  \
# 0  bubbling air and stirring
# 1  bubbling air and stirring
# 2  bubbling air and stirring
# 3                    shaking
# 4                    shaking
#
#                                      inoculum_source  \
# 0                                nitrification basin
# 1                                nitrification basin
# 2                                nitrification basin
# 3  nitrifiying activated sludge form nitrificatio...
# 4  nitrifiying activated sludge form nitrificatio...
#
#                                     location  \
# 0  WWTP Duebendorf (ARA Neugut), Switzerland
# 1  WWTP Duebendorf (ARA Neugut), Switzerland
# 2  WWTP Duebendorf (ARA Neugut), Switzerland
# 3                               Tokyo, Japan
# 4                               Tokyo, Japan
#
#                      purpose_of_wwtp
# 0  mixed WW (municipal & industrial)
# 1  mixed WW (municipal & industrial)
# 2  mixed WW (municipal & industrial)
# 3                              other
# 4                              other
